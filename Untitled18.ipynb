# %% [markdown]
# <a href="https://colab.research.google.com/github/Preetidevidas/covid-19-time-analysis/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#                         **Data Science task**

# %% [markdown]
#                    **Time Analysis of covid-19**

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
from IPython.core.display import display, HTML

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import folium
import plotly.graph_objects as go
import seaborn as sns
import ipywidgets as widgets

# %%
df = r"/content/drive/My Drive/covid19 .xls.xlsx"
d = pd.read_excel(df)

# %%
d.head()
# Out:
#   S. No.           Name of State / UT  ...  Deaths**  Total Confirmed cases*
# 0      1  Andaman and Nicobar Islands  ...       0.0                    33.0
# 1      2               Andhra Pradesh  ...      75.0                  4851.0
# 2      3            Arunachal Pradesh  ...       0.0                    51.0
# 3      4                        Assam  ...       4.0                  2776.0
# 4      5                        Bihar  ...      31.0                  5202.0
#
# [5 rows x 6 columns]

# %%
df1=d[6:18]
df1.plot('Name of State / UT',['Total Confirmed cases*'],kind='bar',colormap='gist_rainbow',figsize=(29,8))

# %%
df1=d[6:18]

# %%
df1.plot.pie(y='Deaths**',x='Name of State / UT',figsize=(30,9),startangle=90,shadow=True,autopct='%1.1f%%')

# %%
px.bar(
    d.head(10),
    x = "Name of State / UT",
    y = "Active Cases*",
    title= "Top 10 worst affected countries", # the axis names
    color_discrete_sequence=["pink"], 
    height=500,
    width=800
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="eea0b1de-3d9d-4b90-8d5f-724d1ea9fc80" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eea0b1de-3d9d-4b90-8d5f-724d1ea9fc80")) {
#                     Plotly.newPlot(
#                         'eea0b1de-3d9d-4b90-8d5f-724d1ea9fc80',
# ...

# %%
px.bar(
    d.head(10),
    x = "Name of State / UT",
    y = "Cured/Discharged/Migrated*",
    title= "cured countries from covid", # the axis names
    color_discrete_sequence=["pink"], 
    height=500,
    width=800
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="25fff9a5-34f4-4d58-bf2a-0cba33919014" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("25fff9a5-34f4-4d58-bf2a-0cba33919014")) {
#                     Plotly.newPlot(
#                         '25fff9a5-34f4-4d58-bf2a-0cba33919014',
# ...
